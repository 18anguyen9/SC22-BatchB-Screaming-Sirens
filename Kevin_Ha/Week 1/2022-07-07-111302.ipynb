# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ijN0ZhBcZlMDjzOH1eMU")
project = rf.workspace("ai-training-data-dog-seeker").project("dog-seeker-rppqw")
dataset = project.version(4).download("yolov5")
# Out:
# ...
#      |█████████                       | 860 kB 44.1 MB/s eta 0:00:01
#      |████████████████████████████████| 3.1 MB 44.1 MB/s
# ...
#      |████████████████████████████████| 145 kB 72.1 MB/s
# ...
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# ...
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# ...
#      |███████████████▊                | 573 kB 65.0 MB/s eta 0:00:01
#      |████████████████████████████████| 1.2 MB 65.0 MB/s
# ...
#      |██▎                             | 1.6 MB 64.5 MB/s eta 0:00:01
#      |███████▊                        | 5.2 MB 64.5 MB/s eta 0:00:01
#      |████████████▌                   | 8.5 MB 64.5 MB/s eta 0:00:01
#      |███████████████████▎            | 13.1 MB 64.5 MB/s eta 0:00:01
#      |██████████████████████████      | 17.7 MB 64.5 MB/s eta 0:00:01
#      |████████████████████████████████| 21.8 MB 64.5 MB/s eta 0:00:01
#      |████████████████████████████████| 21.8 MB 64.5 MB/s
# ...
#   Using cached pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# ...
